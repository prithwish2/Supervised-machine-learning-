# %% [markdown]
# #Read csv file

# %%
import pandas as pd
import numpy as np

df=pd.read_csv("/content/Life Expectancy Data.csv")
df
# Out:
#           Country  Year  ... Income composition of resources  Schooling
# 0     Afghanistan  2015  ...                           0.479       10.1
# 1     Afghanistan  2014  ...                           0.476       10.0
# 2     Afghanistan  2013  ...                           0.470        9.9
# 3     Afghanistan  2012  ...                           0.463        9.8
# 4     Afghanistan  2011  ...                           0.454        9.5
# ...           ...   ...  ...                             ...        ...
# 2933     Zimbabwe  2004  ...                           0.407        9.2
# 2934     Zimbabwe  2003  ...                           0.418        9.5
# 2935     Zimbabwe  2002  ...                           0.427       10.0
# 2936     Zimbabwe  2001  ...                           0.427        9.8
# 2937     Zimbabwe  2000  ...                           0.434        9.8
#
# [2938 rows x 22 columns]

# %% [markdown]
# #Data analysis

# %%
df['Country'].value_counts()    #find the uniqe value in country column
# Out:
# Guatemala    16
# Nepal        16
# Spain        16
# Nicaragua    16
# Bahamas      16
#              ..
# Nauru         1
# Dominica      1
# Palau         1
# Tuvalu        1
# Monaco        1
# Name: Country, Length: 193, dtype: int64

# %%
df['Status'].value_counts()     #unique value in status column
# Out:
# Developing    2426
# Developed      512
# Name: Status, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.isna().sum()   #check the nan value presence
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# #Data preprocessing

# %%
df=df.dropna(axis=0)  #drop all nan value row in dataframe

# %%
df.shape
# Out:
# (1649, 22)

# %%
df.isna().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
from sklearn import preprocessing
x=['Country','Status']
for i in x:
  lable=preprocessing.LabelEncoder()
  df[i]=lable.fit_transform(df[i])
  df[i].unique()
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#       Country  Year  ...  Income composition of resources  Schooling
# 0           0  2015  ...                            0.479       10.1
# 1           0  2014  ...                            0.476       10.0
# 2           0  2013  ...                            0.470        9.9
# 3           0  2012  ...                            0.463        9.8
# 4           0  2011  ...                            0.454        9.5
# ...       ...   ...  ...                              ...        ...
# 2933      132  2004  ...                            0.407        9.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1649 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          1649 non-null   int64
#  1   Year                             1649 non-null   int64
#  2   Status                           1649 non-null   int64
#  3   Life expectancy                  1649 non-null   float64
#  4   Adult Mortality                  1649 non-null   float64
#  5   infant deaths                    1649 non-null   int64
#  6   Alcohol                          1649 non-null   float64
#  7   percentage expenditure           1649 non-null   float64
#  8   Hepatitis B                      1649 non-null   float64
#  9   Measles                          1649 non-null   int64
#  10   BMI                             1649 non-null   float64
#  11  under-five deaths                1649 non-null   int64
# ...

# %% [markdown]
# ## Data visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

_,ax=plt.subplots(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,ax=ax,cmap='Blues')

# %% [markdown]
# This plot shows a correlation between the all feature.

# %%
sns.lineplot(data=df, x="Schooling", y="Life expectancy ")

# %% [markdown]
# This line plot shows that life expectancy increase with schooling.

# %%
sns.lineplot(data=df, x="Income composition of resources", y="Life expectancy ")

# %% [markdown]
# This figure shows that life expectancy lower value arround 0.2 to 0.3 of income composition of resources and high value for arround 0.9 of income composition of resources

# %%
sns.lineplot(data=df, x="Adult Mortality", y="Life expectancy ")

# %% [markdown]
# This figure shows life expectancy decrease with adult mortality

# %%
sns.distplot(df.Population)
plt.title('Population data distribution')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# This plot shows the distribution of the population data. From this plot we can see that most of popolation have in country, Afghanistan according to this dataset.

# %% [markdown]
# # Model building

# %%
x=df.drop(['Life expectancy '],axis=1)
y=df['Life expectancy ']
x.shape
y.shape
# Out:
# (1649,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
lr=LinearRegression().fit(x_train,y_train)
pred=lr.predict(x_test)
s=mean_absolute_error(y_test,pred)
s1=mean_squared_error(y_test,pred)
s2=r2_score(y_test,pred)

print("the MAE with linearRegression: "+str(s))
print("the MSE with LinearRegression: "+str(s1))
print("the r2_score: "+str(s2))
# Out:
# the MAE with linearRegression: 2.7620290506028544
# the MSE with LinearRegression: 12.975720376234255
# the r2_score: 0.8568484538910036
